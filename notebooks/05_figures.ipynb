# %% [markdown]
# # 06 — Figures for the memoire
#
# Generates the 7 publication-ready figures used in the manuscript (PLoS One format, 150 DPI).
#
# **Example participant**: `012WaCh` (3 complete 420 s trials, clean signal, 0 spikes).
#
# ## Figure list
#
# | # | Section | File |
# |---|---|---|
# | 1 | Methods | `fig1_pipeline_preprocessing.png` |
# | 2 | Methods | `fig2_sand_detection.png` |
# | 3 | Methods | `fig3_tde_parameters.png` |
# | 4 | Results | `fig4_torus_3d_simple.png` |
# | 5 | Results | `fig5_resilience_signals.png` |
# | 6 | Results (main) | `fig6_stats_clean.png` |
# | 7 | Results | `fig7_heatmap_ratiovar.png` |
#
# All figures are saved to `outputs/figures/`.

# %%
from resilience.viz import figures_memoire as fm
import matplotlib.pyplot as plt
# %matplotlib inline

fm.setup_style()

# %% [markdown]
# ## Generate all figures

# %%
fm.make_fig1(); plt.show()

# %%
fm.make_fig2(); plt.show()
# Out:
# C:\Users\etulyon1\Desktop\MASTER_IEAP\INTERNSHIP\Stage_M1_2026\src\resilience\viz\figures_memoire.py:66: RuntimeWarning: Mean of empty slice
#   sacrum_xy = np.nanmean(dos_xy, axis=0)

# %%
fm.make_fig3(); plt.show()

# %%
fm.make_fig4(); plt.show()
# Out:
# C:\Users\etulyon1\Desktop\MASTER_IEAP\INTERNSHIP\Stage_M1_2026\src\resilience\viz\figures_memoire.py:66: RuntimeWarning: Mean of empty slice
#   sacrum_xy = np.nanmean(dos_xy, axis=0)

# %%
fm.make_fig5(); plt.show()
# Out:
# C:\Users\etulyon1\Desktop\MASTER_IEAP\INTERNSHIP\Stage_M1_2026\src\resilience\viz\figures_memoire.py:66: RuntimeWarning: Mean of empty slice
#   sacrum_xy = np.nanmean(dos_xy, axis=0)

# %%
fm.make_fig6(); plt.show()

# %%
fm.make_fig7(); plt.show()
